# %%
using Pkg
Pkg.activate(".")

using Crystalline, MPBUtils
using PyCall, Pkg
using PhotonicBandConnectivity, SymmetryBases

include("extra_functions.jl")

const PBC = PhotonicBandConnectivity # just to shorten things up

mp = pyimport("meep")
mpb = pyimport("meep.mpb")
# Out:
#   Activating project at `~/phd/tetb_julia`
# ┌ Warning: PyNormaliz could not be imported: related functionality of SymmetryBases.jl is nonfunctional
# └ @ SymmetryBases /Users/antoniomoralesperez/.julia/packages/SymmetryBases/fpjO6/src/SymmetryBases.jl:26
# PyObject <module 'meep.mpb' from '/opt/homebrew/Caskroom/miniconda/base/envs/mpb/lib/python3.12/site-packages/meep/mpb/__init__.py'>

# %%
R1 = 0.2 #cylinder radius
mat = mp.Medium(epsilon=12)
geometry = [
    mp.Cylinder(radius=R1, center=[0, 0, 0], axis=[0, 0, 1], height=1, material=mat),
    mp.Cylinder(radius=R1, center=[0, 0, 0], axis=[0, 1, 0], height=1, material=mat),
    mp.Cylinder(radius=R1, center=[0, 0, 0], axis=[1, 0, 0], height=1, material=mat),
]
ms = mpb.ModeSolver(
    num_bands=8,
    geometry_lattice=mp.Lattice(basis1=[1, 0, 0], basis2=[0, 1, 0], basis3=[0, 0, 1],
        size=[1, 1, 1]),
    geometry=geometry,
    resolution=32,
)
ms.init_params(p=mp.ALL, reset_fields=true)

### obtain the symmetry vectors of the bands under study
sg_num = 221
band_summaries = obtain_symmetry_vectors(ms, sg_num)

vᵀ = band_summaries[1] # pick the 2 lower bands
# Out:
# Working in 3 dimensions.
# Grid size is 32 x 32 x 32.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1, axis (0, 1, 0)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1, axis (1, 0, 0)
# Geometric object tree has depth 7 and 15 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# solve_kpoint (0.5,0.5,0):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 13.97841909802288 (196.447% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 2.011587438881433 (149.679% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.502293227413622 (28.9876% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.364253162332093 (9.63111% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.317821423430793 (3.46237% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.302345895391319 (1.18126% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.295868729553887 (0.498586% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.292642166312252 (0.249299% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.291276555900218 (0.105701% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.29026279434604 (0.0785393% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.28940060615731 (0.066845% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 1.288315751528129 (0.0841718% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.287160261492923 (0.0897302% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.286251320670241 (0.0706409% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.285485972423362 (0.0595199% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 1.28492625054946 (0.0435511% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 1.284402229822935 (0.0407905% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 1.283878475671522 (0.0407864% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 1.283381807958151 (0.0386924% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 1.282915128364632 (0.0363699% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 1.282599052163084 (0.0246404% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 1.282409814967918 (0.0147553% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 1.282295016541017 (0.00895217% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 1.28224077043057 (0.00423048% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.282211611970854 (0.00227405% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 1.282196811062048 (0.00115433% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 1.282188930685553 (0.000614601% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 1.282183785651474 (0.00040127% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 1.282180830553564 (0.000230474% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 1.282179096115882 (0.000135273% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 1.282178097030682 (7.79209e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 1.282177611828222 (3.78421e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 1.282177337676927 (2.13817e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 1.282177154040778 (1.43222e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 1.282176998459535 (1.21341e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 1.282176820911153 (1.38474e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 1.282176651053298 (1.32476e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 1.282176524271908 (9.88798e-06% change)
# Finished solving for bands 1 to 8 after 38 iterations.
# freqs:, 1, 0.5, 0.5, 0, 0.707107, 0.266656, 0.317439, 0.373773, 0.403224, 0.403273, 0.436872, 0.436875, 0.513481
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 1.599080762158076 (31.5337% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.505213225684689 (6.04759% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 1.481134309544031 (1.6126% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.462072498852826 (1.29531% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 1.447914830584437 (0.97304% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 1.427945417886909 (1.38876% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.406478470529738 (1.51473% change)
#     linmin: converged after 6 iterations.
#     iteration    8: trace = 1.379875612064084 (1.90951% change)
#     linmin: converged after 5 iterations.
#     iteration    9: trace = 1.364213147453447 (1.14154% change)
#     linmin: converged after 5 iterations.
#     iteration   10: trace = 1.350676898945335 (0.997186% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 1.343990906361266 (0.496239% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.34038495348629 (0.268662% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.338188421819932 (0.164008% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 1.336951916355254 (0.0924442% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.336101490181965 (0.0636296% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.335692580186977 (0.0306094% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.335510847269961 (0.0136068% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.335415619890008 (0.00713066% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.335380616999063 (0.00262116% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.335362594827215 (0.0013496% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.335354323999466 (0.000619371% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.335351136886173 (0.000238672% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.335349340454671 (0.000134529% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.335348287192472 (7.88754e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.335347099413383 (8.89491e-05% change)
#     large trace change predicted (0.000224887%)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 1.335344096787191 (0.000224858% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   27: trace = 1.335216978487767 (0.00951997% change)
#     linmin: converged after 6 iterations.
#     iteration   28: trace = 1.33518591682248 (0.00232637% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 1.335162891877178 (0.00172449% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 1.335143715188106 (0.00143629% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 1.335126784469804 (0.00126809% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 1.335111350140909 (0.00115603% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 1.335097013213557 (0.00107384% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 1.335083543760422 (0.00100888% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 1.335070801286769 (0.000954437% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 1.33505869420103 (0.000906854% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 1.335047156771471 (0.000864193% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 1.335036135145901 (0.000825564% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 1.335025578782566 (0.000790721% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 1.335015435470409 (0.000759787% change)
#     linmin: converged after 4 iterations.
#     iteration   41: trace = 1.335005648823661 (0.000733076% change)
#     linmin: converged after 4 iterations.
#     iteration   42: trace = 1.33499615742413 (0.000710966% change)
#     linmin: converged after 4 iterations.
#     iteration   43: trace = 1.334986894951408 (0.000693823% change)
#     linmin: converged after 4 iterations.
#     iteration   44: trace = 1.334977790790903 (0.000681969% change)
#     linmin: converged after 4 iterations.
#     iteration   45: trace = 1.334968770762212 (0.000675671% change)
#     linmin: converged after 4 iterations.
#     iteration   46: trace = 1.334959757751729 (0.00067515% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 1.334950672145142 (0.000680593% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 1.334941432033845 (0.000692171% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 1.334931953219439 (0.000710057% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 1.334922149032948 (0.000734436% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 1.334911930049917 (0.000765514% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 1.334901203694746 (0.000803529% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 1.334889873803231 (0.000848747% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 1.334877840184916 (0.000901473% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 1.334864998275367 (0.000962033% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 1.33485123903748 (0.00103076% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 1.334836449388844 (0.00110797% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 1.334820513613057 (0.00119384% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 1.334803316463126 (0.00128836% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 1.334784748973209 (0.00139104% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 1.334764718278761 (0.00150068% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 1.334743162784769 (0.00161494% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 1.334720073357404 (0.00172989% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 1.334695519142215 (0.00183967% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 1.334669672571112 (0.00193653% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 1.33464282287763 (0.00201173% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 1.33461536458527 (0.00205737% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 1.334587752689704 (0.00206892% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 1.33456043151152 (0.00204718% change)
#     resetting CG direction...
#     large trace change predicted (0.283532%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 1.330776193101998 (0.28396% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 1.324033266326333 (0.507978% change)
#     linmin: converged after 3 iterations.
#     iteration   72: trace = 1.32178904237584 (0.169643% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 1.321083177606521 (0.0534165% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 1.320544977086114 (0.0407476% change)
#     linmin: converged after 4 iterations.
#     iteration   75: trace = 1.320060179606464 (0.0367187% change)
#     linmin: converged after 3 iterations.
#     iteration   76: trace = 1.319793966264124 (0.0201688% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 1.319706358627582 (0.0066382% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 1.319656806113009 (0.00375488% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 1.319575460295493 (0.00616435% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 1.319527130165609 (0.00366262% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 1.319501061879243 (0.0019756% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 1.319485546445155 (0.00117586% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 1.319474322419918 (0.00085064% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 1.319465536019655 (0.000665904% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 1.319460962663721 (0.000346607% change)
#     linmin: converged after 2 iterations.
#     iteration   86: trace = 1.319458820498819 (0.000162352% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 1.319456980867146 (0.000139423% change)
#     linmin: converged after 2 iterations.
#     iteration   88: trace = 1.31945597461117 (7.62629e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   89: trace = 1.319454994454892 (7.42849e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   90: trace = 1.319454394011478 (4.55069e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   91: trace = 1.319454036920471 (2.70635e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   92: trace = 1.319453724308811 (2.36925e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   93: trace = 1.319453448714196 (2.0887e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   94: trace = 1.319453235180613 (1.61835e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   95: trace = 1.319453144998252 (6.83483e-06% change)
# Finished solving for bands 1 to 8 after 95 iterations.
# freqs:, 2, 0, 0.5, 0, 0.5, 0.226456, 0.226463, 0.345201, 0.345237, 0.454862, 0.504262, 0.504325, 0.512844
# solve_kpoint (0,0,0):
# Solving for bands 3 to 8...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 1.585562377908179 (48.5533% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 1.428499740118084 (10.422% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.370097497614445 (4.17368% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.347119728616242 (1.69127% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.336900015254796 (0.761523% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.32786253220375 (0.678296% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.318418177004334 (0.713783% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.304741164239116 (1.04279% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.29621286633173 (0.655782% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.289194649569463 (0.54291% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.286379617346482 (0.218595% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 1.285051464736373 (0.103301% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 1.284434166253037 (0.0480484% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.284211730263597 (0.0173193% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.284091412382287 (0.00936945% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.284043618221283 (0.00372209% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.284018728411296 (0.00193841% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.284008544363811 (0.000793142% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.284003286766398 (0.000409468% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.283999396610053 (0.000302971% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.283996969987662 (0.00018899% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.283995766304553 (9.37451e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.283995249830713 (4.0224e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.283995090579292 (1.24028e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.283995016401389 (5.77712e-06% change)
# Finished solving for bands 3 to 8 after 25 iterations.
# freqs:, 3, 0, 0, 0, 0, 0, 0, 0.445695, 0.44573, 0.445742, 0.478879, 0.478881, 0.478891
# solve_kpoint (0.5,0.5,0.5):
# Solving for bands 1 to 8...
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 2.231492022430751 (58.4394% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 1.731661357643947 (25.2239% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 1.459738050827066 (17.041% change)
#     linmin: converged after 6 iterations.
#     iteration    4: trace = 1.332957695034673 (9.07942% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 1.286478165822214 (3.54882% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 1.270809880680954 (1.22538% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 1.266390922595059 (0.348333% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.265095105723299 (0.102376% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.264726096132595 (0.0291728% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.264585086177942 (0.0111501% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.264544753839837 (0.00318942% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.264531545321447 (0.00104453% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 1.264527682810212 (0.00030545% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 1.264526735977495 (7.48764e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 1.264526438723101 (2.35072e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.264526334155865 (8.26928e-06% change)
# Finished solving for bands 1 to 8 after 16 iterations.
# freqs:, 4, 0.5, 0.5, 0.5, 0.866025, 0.334633, 0.334645, 0.399751, 0.399801, 0.399813, 0.432453, 0.432454, 0.432476
# 2-band BandSummary:
#  bands:      1:2
#  n:          -Γ₁⁺+Γ₄⁻, R₃⁺, M₂⁺+M₃⁻, X₅⁻
#  topology:   fragile

# %%
t = 1
brs = bandreps(sg_num)
d = matrix(brs)[end, :]

long_modes = find_auxiliary_modes(t, d, brs)

band_repre = find_all_band_representations(vᵀ, long_modes, d, brs)

nᵀ⁺ᴸ = brs[band_repre[2][1][1]...]
nᴸ = brs[band_repre[2][2]...]

println("nᵀ⁺ᴸ", " = ", nᵀ⁺ᴸ.label, " at ", nᵀ⁺ᴸ.wyckpos, "; nᴸ", " = ", nᴸ.label, " at ", nᴸ.wyckpos)
# Out:
# nᵀ⁺ᴸ = A₂g↑G at 3c; nᴸ = A₁ᵤ↑G at 1b

# %%
typeof(([[34]], [1], [true]))
# Out:
# Tuple{Vector{Vector{Int64}}, Vector{Int64}, Vector{Bool}}

# %%
output = Tuple{Vector{Vector{Int64}},Vector{Int64},Vector{Bool}}[]
push!(output, ([[34]], [1], [true]))
# Out:
# 1-element Vector{Tuple{Vector{Vector{Int64}}, Vector{Int64}, Vector{Bool}}}:
#  ([[34]], [1], [1])
